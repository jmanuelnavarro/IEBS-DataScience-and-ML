# %% [markdown]
# # Lectura y análisis de los datos disponibles

# %%
# Import numpy and pandas library
import numpy as np
import pandas as pd

# %% [markdown]
# ## Lectura de los datos y carga en un dataframe

# %%
df_telco_cust_churn = pd.read_csv('../data/external/datasets_13996_18858_WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %% [markdown]
# ## Entendimiento de los datos leídos

# %% [markdown]
# ## Análisis de los datos leídos

# %%
# Cantidad de datos
print(f'Disponesmos de datos de {len(df_telco_cust_churn)} clientes')
# Out:
# Disponesmos de datos de 7043 clientes

# %%
# Muestreo de los datos de clientes
df_telco_cust_churn.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 64    5698-BQJOH  Female              0      No         No       9
# 2748  2495-INZWQ    Male              0      No         No       4
# 1606  6374-NTQLP    Male              1     Yes        Yes      72
# 6427  6000-UKLWI    Male              0      No         No      41
# 1620  6022-KOUQO  Female              0     Yes        Yes       2
# 6245  4759-PXTAN  Female              0     Yes         No      59
# 4511  3633-CDBUW    Male              0      No        Yes      17
# 2191  3988-RQIXO  Female              1      No         No       1
# 6250  3705-RHRFR  Female              0     Yes         No      69
# 4405  8417-FMLZI    Male              0     Yes        Yes       6
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 64            Yes               Yes     Fiber optic                   No  ...
# ...

# %%
# Ordenación según los cargos
df_telco_cust_churn.sort_values(['TotalCharges','MonthlyCharges'], ascending=[False, False]).head(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2845  9093-FPDLG  Female              0      No         No      11
# 3353  4536-PLEQY    Male              0     Yes         No      12
# 3686  5899-MQZZL  Female              0      No         No      13
# 5598  6051-PTVNS  Female              0     Yes        Yes      55
# 6646  8249-THVEC    Male              0     Yes        Yes      51
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 2845          Yes            No     Fiber optic                   No  ...
# 3353          Yes            No     Fiber optic                   No  ...
# 3686          Yes           Yes     Fiber optic                   No  ...
# 5598          Yes            No              No  No internet service  ...
# 6646          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
# Agrupamiento por gender
df_telco_cust_churn.groupby(['gender']).sum()
# Out:
#         SeniorCitizen  tenure  MonthlyCharges
# gender
# Female            568  112469        227432.4
# Male              574  115521        228684.2

# %%
df_telco_cust_churn[df_telco_cust_churn['gender'] == 'Male']
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 2     3668-QPYBK   Male              0      No         No       2
# 3     7795-CFOCW   Male              0      No         No      45
# 6     1452-KIOVK   Male              0      No        Yes      22
# 9     6388-TABGU   Male              0      No        Yes      62
# ...          ...    ...            ...     ...        ...     ...
# 7033  9767-FFLEM   Male              0      No         No      38
# 7035  8456-QDAVC   Male              0      No         No      19
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7041  8361-LTMKD   Male              1     Yes         No       4
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
df_telco_cust_churn.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df_telco_cust_churn['tenure'].min()
# Out:
# 0

# %%
df_telco_cust_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
df_telco_cust_churn.describe(include='object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     1591-NFNLQ   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %% [markdown]
# ### Análisis de posibles outliers y valores anómalos
